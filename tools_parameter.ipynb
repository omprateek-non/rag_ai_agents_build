# %%
# !pip install langchain langchain-core langchain-community duckduckgo-search langchain_experimental openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 77.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.2/211.2 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
print('Fixing requests dependency conflict...')
# !pip install requests==2.32.4
# Out:
# Fixing requests dependency conflict...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.34.2
#     Uninstalling requests-2.34.2:
#       Successfully uninstalled requests-2.34.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4.2 requires requests<3.0.0,>=2.32.5, but you have requests 2.32.4 which is incompatible.
# ...

# %%
# !pip install -U ddgs
from langchain_community.tools import DuckDuckGoSearchRun
search_tool = DuckDuckGoSearchRun()
results = search_tool.invoke('todays news')

print(results)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 3.5 MB/s eta 0:00:00
# ...
# Never Miss a Beat: Install Breaking News Today. Download Breaking News Free & Safely. Install & Use · Get Latest Now · Secure Install · Get Free App Stay Informed About The Newest Global & Local News. Sign Up Today! Here is the News app everyone is using. You have to get one on your phone. Download the latest version of Breaking News US for free with no registration needed! Download Breaking News US now on PC, 100% free with no registration needed! View the latest news and breaking news today for U.S., world, weather, entertainment, politics and health at CNN.com. Go to NBCNews.com for breaking news, videos, and the latest top stories in world news, business, politics, health and pop culture.

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results= shell_tool.invoke('whoami')

print(results)
# Out:
# Executing command:
#  whoami
# root
# /usr/local/lib/python3.13/dist-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %%
from pydantic import BaseModel, Field
from langchain.tools import tool

class WeatherInput(BaseModel):
    city: str = Field(description="The city name for which to get the weather.")

@tool("get_weather", args_schema=WeatherInput)
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    # In a real scenario, you'd fetch actual weather data here.
    # For this example, we'll return a static message.
    print(f"Looking up data for city: {city}") # Simulate writer output
    print(f"Acquired data for city: {city}") # Simulate writer output
    return f"It's always sunny in {city}!"

# %%
from langchain.tools import BaseTool
from typing import Type

# %%
class MultiplyInput(BaseModel):
  a: int = Field(description="First number")
  b: int = Field(description="Second number")

# %%
class MultiplyInput(BaseTool):
  name: str="mulitiply"
  description: str= "Multiply two numbers"

  args_schema : Type[BaseModel] = MultiplyInput

  def _run(self,a :int,b:int)->int:
    return a*b

# %%
import os
# !pip install -U langchain-google-genai

# os.environ['GEMINI_API_KEY'] = "YjTRgGVL9JJo45b6LCAggZWTrMdpGA2a9Xjnuk8gBQ"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 19.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.58.0 which is incompatible.
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage

# %%
@tool
def multiply(a:int,b:int)-> int:
  """Given 2numbers a and b this tool returns thier product"""

  return a*b

# %%
print(multiply.invoke({'a':3,'b':4}))
# Out:
# 12

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2numbers a and b this tool returns thier product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
llm = ChatGoogleGenerativeAI

# %%
@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> dict:
  """
  This function fetches the currency factor between a given base currency and a target currency
  """
  import requests
  url = f'https://v6.exchangerate-api.com/v6/0b99f2baa745d80f2b7f6a62/pair/{base_currency}/{target_currency}'
  response = requests.get(url)
  return response.json()

@tool
def convert(base_value: float, conversion_rate: float) -> float:
  """
  Given a currency conversion rate, this function calculates the target currency value from a given base currency value.
  """
  return base_value * conversion_rate

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1789171201,
#  'time_last_update_utc': 'Sat, 12 Sep 2026 00:00:01 +0000',
#  'time_next_update_unix': 1789257601,
#  'time_next_update_utc': 'Sun, 13 Sep 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'INR',
#  'conversion_rate': 95.6045}

# %%
convert.invoke({'base_value': 10, 'conversion_rate': 95.5306})
# Out:
# 955.306

# %%
llm = ChatGoogleGenerativeAI

# %%
# 1. Properly instantiate the model
# Replace 'YOUR_API_KEY' with your actual Gemini API key
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash", google_api_key="YOUR_API_KEY")

# 2. Now bind the tools to the instance
llm_with_tools = llm.bind_tools([get_conversion_factor, convert])
